# %% [markdown]
# Q.1 Define the role of a Data Analyst in your own words. What value do they bring to an organization?
#
# ANS :- THE KEY ROLE OF THE DATA ANALYST IS CLEARING THE DATA, MASTARING THE DATA VISULIAZE, THE DATA TO MAKE GOOD DECISION FOR THE COMPANY.
